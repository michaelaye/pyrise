# %%
from hirise import hirise_tools as ht

# %%
obsid = ht.OBSERVATION_ID('PSP_003072_0985')

# %%
obsid.orbit
# Out:
# '003072'

# %%
obsid.orbit = 4080

# %%
obsid.orbit
# Out:
# '004080'

# %%
obsid
# Out:
# PSP_004080_0985

# %%
obsid.targetcode
# Out:
# '0985'

# %%
obsid.targetcode = '0980'

# %%
obsid.targetcode
# Out:
# '0980'

# %%
obsid
# Out:
# PSP_004080_0980
